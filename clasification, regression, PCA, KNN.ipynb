# %% [markdown]
# # importing required libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # importing the dataset

# %%
bs = pd.read_csv('D:/bs140513_032310 (1).csv')

# %%
bs
# Out:
#         step       customer  age gender zipcodeOri       merchant zipMerchant  \
# 0          0  'C1093826151'  '4'    'M'    '28007'   'M348934600'     '28007'
# 1          0   'C352968107'  '2'    'M'    '28007'   'M348934600'     '28007'
# 2          0  'C2054744914'  '4'    'F'    '28007'  'M1823072687'     '28007'
# 3          0  'C1760612790'  '3'    'M'    '28007'   'M348934600'     '28007'
# 4          0   'C757503768'  '5'    'M'    '28007'   'M348934600'     '28007'
# ...      ...            ...  ...    ...        ...            ...         ...
# 594638   179  'C1753498738'  '3'    'F'    '28007'  'M1823072687'     '28007'
# 594639   179   'C650108285'  '4'    'F'    '28007'  'M1823072687'     '28007'
# 594640   179   'C123623130'  '2'    'F'    '28007'   'M349281107'     '28007'
# 594641   179  'C1499363341'  '5'    'M'    '28007'  'M1823072687'     '28007'
# 594642   179   'C616528518'  '4'    'F'    '28007'  'M1823072687'     '28007'
#
# ...

# %%
bs.head()
# Out:
#    step       customer  age gender zipcodeOri       merchant zipMerchant  \
# 0     0  'C1093826151'  '4'    'M'    '28007'   'M348934600'     '28007'
# 1     0   'C352968107'  '2'    'M'    '28007'   'M348934600'     '28007'
# 2     0  'C2054744914'  '4'    'F'    '28007'  'M1823072687'     '28007'
# 3     0  'C1760612790'  '3'    'M'    '28007'   'M348934600'     '28007'
# 4     0   'C757503768'  '5'    'M'    '28007'   'M348934600'     '28007'
#
#               category  amount  fraud
# 0  'es_transportation'    4.55      0
# 1  'es_transportation'   39.68      0
# 2  'es_transportation'   26.89      0
# 3  'es_transportation'   17.25      0
# 4  'es_transportation'   35.72      0

# %%
bs.tail()
# Out:
#         step       customer  age gender zipcodeOri       merchant zipMerchant  \
# 594638   179  'C1753498738'  '3'    'F'    '28007'  'M1823072687'     '28007'
# 594639   179   'C650108285'  '4'    'F'    '28007'  'M1823072687'     '28007'
# 594640   179   'C123623130'  '2'    'F'    '28007'   'M349281107'     '28007'
# 594641   179  'C1499363341'  '5'    'M'    '28007'  'M1823072687'     '28007'
# 594642   179   'C616528518'  '4'    'F'    '28007'  'M1823072687'     '28007'
#
#                    category  amount  fraud
# 594638  'es_transportation'   20.53      0
# 594639  'es_transportation'   50.73      0
# 594640         'es_fashion'   22.44      0
# 594641  'es_transportation'   14.46      0
# 594642  'es_transportation'   26.93      0

# %% [markdown]
# # data preprocessing

# %%
bs.dtypes
# Out:
# step             int64
# customer        object
# age             object
# gender          object
# zipcodeOri      object
# merchant        object
# zipMerchant     object
# category        object
# amount         float64
# fraud            int64
# dtype: object

# %% [markdown]
# # null values and duplicate values checking

# %%
bs.isnull()
# Out:
#          step  customer    age  gender  zipcodeOri  merchant  zipMerchant  \
# 0       False     False  False   False       False     False        False
# 1       False     False  False   False       False     False        False
# 2       False     False  False   False       False     False        False
# 3       False     False  False   False       False     False        False
# 4       False     False  False   False       False     False        False
# ...       ...       ...    ...     ...         ...       ...          ...
# 594638  False     False  False   False       False     False        False
# 594639  False     False  False   False       False     False        False
# 594640  False     False  False   False       False     False        False
# 594641  False     False  False   False       False     False        False
# 594642  False     False  False   False       False     False        False
#
#         category  amount  fraud
# 0          False   False  False
# ...

# %% [markdown]
# # printing the null values

# %%
print('We have {} NaN/Null values in data'.format(bs.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in data

# %%
bs.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 594638    False
# 594639    False
# 594640    False
# 594641    False
# 594642    False
# Length: 594643, dtype: bool

# %% [markdown]
# # printing duplicate values

# %%
print('No of duplicates in data: {}'.format(sum(bs.duplicated())))
# Out:
# No of duplicates in data: 0

# %% [markdown]
# # converting categorical string value into numerical

# %%
bs[["gender"]] = bs[["gender"]].apply(lambda col:pd.Categorical(col).codes)

# %%
bs
# Out:
#         step       customer  age  gender zipcodeOri       merchant  \
# 0          0  'C1093826151'  '4'       2    '28007'   'M348934600'
# 1          0   'C352968107'  '2'       2    '28007'   'M348934600'
# 2          0  'C2054744914'  '4'       1    '28007'  'M1823072687'
# 3          0  'C1760612790'  '3'       2    '28007'   'M348934600'
# 4          0   'C757503768'  '5'       2    '28007'   'M348934600'
# ...      ...            ...  ...     ...        ...            ...
# 594638   179  'C1753498738'  '3'       1    '28007'  'M1823072687'
# 594639   179   'C650108285'  '4'       1    '28007'  'M1823072687'
# 594640   179   'C123623130'  '2'       1    '28007'   'M349281107'
# 594641   179  'C1499363341'  '5'       2    '28007'  'M1823072687'
# 594642   179   'C616528518'  '4'       1    '28007'  'M1823072687'
#
#        zipMerchant             category  amount  fraud
# 0          '28007'  'es_transportation'    4.55      0
# ...

# %% [markdown]
# # removing single quote from the numerical value

# %%
bs['customer']=bs['customer'].str.replace("[']", "")

# %%
bs['age']=bs['age'].str.replace("[']", "")

# %%
bs['zipcodeOri']=bs['zipcodeOri'].str.replace("[']", "")

# %%
bs['merchant']=bs['merchant'].str.replace("[']", "")

# %%
bs['zipMerchant']=bs['zipMerchant'].str.replace("[']", "")

# %%
bs['category']=bs['category'].str.replace("[']", "")

# %%
bs
# Out:
#         step     customer age  gender zipcodeOri     merchant zipMerchant  \
# 0          0  C1093826151   4       2      28007   M348934600       28007
# 1          0   C352968107   2       2      28007   M348934600       28007
# 2          0  C2054744914   4       1      28007  M1823072687       28007
# 3          0  C1760612790   3       2      28007   M348934600       28007
# 4          0   C757503768   5       2      28007   M348934600       28007
# ...      ...          ...  ..     ...        ...          ...         ...
# 594638   179  C1753498738   3       1      28007  M1823072687       28007
# 594639   179   C650108285   4       1      28007  M1823072687       28007
# 594640   179   C123623130   2       1      28007   M349281107       28007
# 594641   179  C1499363341   5       2      28007  M1823072687       28007
# 594642   179   C616528518   4       1      28007  M1823072687       28007
#
#                  category  amount  fraud
# ...

# %%
bs[["category"]] = bs[["category"]].apply(lambda col:pd.Categorical(col).codes)

# %%
bs
# Out:
#         step     customer age  gender zipcodeOri     merchant zipMerchant  \
# 0          0  C1093826151   4       2      28007   M348934600       28007
# 1          0   C352968107   2       2      28007   M348934600       28007
# 2          0  C2054744914   4       1      28007  M1823072687       28007
# 3          0  C1760612790   3       2      28007   M348934600       28007
# 4          0   C757503768   5       2      28007   M348934600       28007
# ...      ...          ...  ..     ...        ...          ...         ...
# 594638   179  C1753498738   3       1      28007  M1823072687       28007
# 594639   179   C650108285   4       1      28007  M1823072687       28007
# 594640   179   C123623130   2       1      28007   M349281107       28007
# 594641   179  C1499363341   5       2      28007  M1823072687       28007
# 594642   179   C616528518   4       1      28007  M1823072687       28007
#
#         category  amount  fraud
# 0             12    4.55      0
# ...

# %% [markdown]
# # dropping the string value

# %%
bs=bs.drop("customer", axis=1)

# %%
bs=bs.drop("merchant", axis=1)

# %%
bs
# Out:
#         step age  gender zipcodeOri zipMerchant  category  amount  fraud
# 0          0   4       2      28007       28007        12    4.55      0
# 1          0   2       2      28007       28007        12   39.68      0
# 2          0   4       1      28007       28007        12   26.89      0
# 3          0   3       2      28007       28007        12   17.25      0
# 4          0   5       2      28007       28007        12   35.72      0
# ...      ...  ..     ...        ...         ...       ...     ...    ...
# 594638   179   3       1      28007       28007        12   20.53      0
# 594639   179   4       1      28007       28007        12   50.73      0
# 594640   179   2       1      28007       28007         2   22.44      0
# 594641   179   5       2      28007       28007        12   14.46      0
# 594642   179   4       1      28007       28007        12   26.93      0
#
# [594643 rows x 8 columns]

# %% [markdown]
# # droping the string value from age column

# %%
i = bs[((bs.age == 'U'))].index

# %%
bs = bs.drop(i)

# %%
bs
# Out:
#         step age  gender zipcodeOri zipMerchant  category  amount  fraud
# 0          0   4       2      28007       28007        12    4.55      0
# 1          0   2       2      28007       28007        12   39.68      0
# 2          0   4       1      28007       28007        12   26.89      0
# 3          0   3       2      28007       28007        12   17.25      0
# 4          0   5       2      28007       28007        12   35.72      0
# ...      ...  ..     ...        ...         ...       ...     ...    ...
# 594638   179   3       1      28007       28007        12   20.53      0
# 594639   179   4       1      28007       28007        12   50.73      0
# 594640   179   2       1      28007       28007         2   22.44      0
# 594641   179   5       2      28007       28007        12   14.46      0
# 594642   179   4       1      28007       28007        12   26.93      0
#
# [593465 rows x 8 columns]

# %% [markdown]
# # splitting the data

# %%
x=bs.drop("fraud", axis=1)

# %%
x
# Out:
#         step age  gender zipcodeOri zipMerchant  category  amount
# 0          0   4       2      28007       28007        12    4.55
# 1          0   2       2      28007       28007        12   39.68
# 2          0   4       1      28007       28007        12   26.89
# 3          0   3       2      28007       28007        12   17.25
# 4          0   5       2      28007       28007        12   35.72
# ...      ...  ..     ...        ...         ...       ...     ...
# 594638   179   3       1      28007       28007        12   20.53
# 594639   179   4       1      28007       28007        12   50.73
# 594640   179   2       1      28007       28007         2   22.44
# 594641   179   5       2      28007       28007        12   14.46
# 594642   179   4       1      28007       28007        12   26.93
#
# [593465 rows x 7 columns]

# %%
y=bs["fraud"]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 594638    0
# 594639    0
# 594640    0
# 594641    0
# 594642    0
# Name: fraud, Length: 593465, dtype: int64

# %% [markdown]
# # train test splitting

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
x_train
# Out:
#         step age  gender zipcodeOri zipMerchant  category  amount
# 148426    52   5       2      28007       28007        12   39.20
# 150370    53   2       2      28007       28007        12   22.02
# 556555   169   3       1      28007       28007        12    8.32
# 431646   135   3       1      28007       28007        12   32.00
# 168751    59   6       2      28007       28007        12   25.43
# ...      ...  ..     ...        ...         ...       ...     ...
# 372117   119   2       2      28007       28007        12    9.36
# 492227   152   2       2      28007       28007        12   29.51
# 471848   146   3       2      28007       28007        12   13.41
# 492720   152   6       1      28007       28007         7   57.12
# 128240    45   2       1      28007       28007        12   19.66
#
# [474772 rows x 7 columns]

# %%
y_train
# Out:
# 148426    0
# 150370    0
# 556555    0
# 431646    0
# 168751    0
#          ..
# 372117    0
# 492227    0
# 471848    0
# 492720    0
# 128240    0
# Name: fraud, Length: 474772, dtype: int64

# %%
x_test
# Out:
#         step age  gender zipcodeOri zipMerchant  category  amount
# 392572   124   5       2      28007       28007        12   23.98
# 133826    47   3       1      28007       28007        12   42.27
# 506587   156   3       1      28007       28007        12   30.46
# 233813    79   2       1      28007       28007        12   18.72
# 341572   110   2       1      28007       28007        14   18.94
# ...      ...  ..     ...        ...         ...       ...     ...
# 466853   145   2       1      28007       28007        12   45.79
# 167688    58   2       1      28007       28007        12   33.06
# 177015    61   5       1      28007       28007        12   46.49
# 467590   145   4       1      28007       28007        12   20.96
# 249335    83   5       2      28007       28007        12   36.55
#
# [118693 rows x 7 columns]

# %%
y_test
# Out:
# 392572    0
# 133826    0
# 506587    0
# 233813    0
# 341572    0
#          ..
# 466853    0
# 167688    0
# 177015    0
# 467590    0
# 249335    0
# Name: fraud, Length: 118693, dtype: int64

# %% [markdown]
# # classification

# %% [markdown]
# # random forest classification

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf =RandomForestClassifier(n_estimators=100)

# %% [markdown]
# # fitting the model

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rf.predict(x_test)

# %% [markdown]
# # accuracy prediction

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9943214848390385

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[117074,    504],
#        [   170,    945]], dtype=int64)

# %% [markdown]
# # decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()

# %% [markdown]
# # fitting the model

# %%
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dtc.predict(x_test)

# %% [markdown]
# # accuracy score throgh dtc

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9912463245515742

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[116697,    492],
#        [   547,    957]], dtype=int64)

# %%
from sklearn import tree

# %%
tree.plot_tree(dtc)
# Out:
# [Text(288.5546074433155, 230.56744186046512, 'X[6] <= 261.125\ngini = 0.024\nsamples = 474772\nvalue = [469028, 5744]'),
#  Text(220.87989873153413, 225.14232558139534, 'X[6] <= 151.825\ngini = 0.01\nsamples = 470668\nvalue = [468340, 2328]'),
#  Text(152.54424624958355, 219.71720930232559, 'X[6] <= 94.525\ngini = 0.006\nsamples = 465568\nvalue = [464212, 1356]'),
#  Text(106.76364634296512, 214.2920930232558, 'X[5] <= 11.5\ngini = 0.004\nsamples = 456985\nvalue = [456120, 865]'),
#  Text(74.43691584827016, 208.86697674418605, 'X[5] <= 7.5\ngini = 0.031\nsamples = 44224\nvalue = [43523, 701]'),
#  Text(36.45781868569729, 203.4418604651163, 'X[5] <= 3.5\ngini = 0.019\nsamples = 41623\nvalue = [41217, 406]'),
#  Text(8.442510982184825, 198.0167441860465, 'X[5] <= 2.5\ngini = 0.004\nsamples = 29768\nvalue = [29710, 58]'),
#  Text(8.314393206824601, 192.59162790697675, 'X[0] <= 109.5\ngini = 0.012\nsamples = 9272\nvalue = [9214, 58]'),
# ...

# %% [markdown]
# # naive_bayes classifier

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
nb = BernoulliNB()

# %% [markdown]
# # model fitting

# %%
nb.fit(x_test,y_test)
# Out:
# BernoulliNB()

# %% [markdown]
# # predition with naive_bayes

# %%
y_pred = nb.predict(x_test)

# %% [markdown]
# # accuracy score through nb

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9877920349136007

# %% [markdown]
# # regression

# %%
from sklearn import datasets, linear_model, metrics

# %% [markdown]
# # linear regression

# %%
linearreg= linear_model.LinearRegression()

# %%
linearreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: ', linearreg.coef_)
# Out:
# Coefficients:  [-2.05148974e-05 -8.78825230e-05 -3.92399477e-03  0.00000000e+00
#   0.00000000e+00 -2.64233359e-03  4.66483838e-04]

# %% [markdown]
# # prediction

# %%
y_pred=linearreg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
y_pred
# Out:
# array([0.00023868, 0.01445008, 0.00670478, ..., 0.01595567, 0.00241097,
#        0.0069435 ])

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 0.008956557276474238

# %%
print('score: {}'.format(linearreg.score(x_test, y_test)))
# Out:
# score: 0.2572677032504237

# %%
plt.style.use('fivethirtyeight')
plt.scatter(linearreg.predict(x_train), linearreg.predict(x_train) - y_train, color = "green", s = 10)

# %%
plt.scatter(linearreg.predict(x_test), linearreg.predict(x_test) - y_test,color = "red", s = 10)

# %% [markdown]
# # random forest regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
randomregressor = RandomForestRegressor()

# %% [markdown]
# # fitting the model

# %%
randomregressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
Y_pred = randomregressor.predict(x_test)

# %% [markdown]
# # regression score

# %%
print('score: {}'.format(randomregressor.score(x_test, y_test)))
# Out:
# score: 0.5990142345719224

# %% [markdown]
# # clusturing

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn= KNeighborsClassifier(n_neighbors=7)

# %% [markdown]
# # fitting the model

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred = (knn.predict(x_test))

# %%
print(knn.score(x_test, y_test))
# Out:
# 0.9936559022014778

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    117244
#            1       0.83      0.60      0.70      1449
#
#     accuracy                           0.99    118693
#    macro avg       0.91      0.80      0.85    118693
# weighted avg       0.99      0.99      0.99    118693

# %% [markdown]
# # principle component analysis

# %%
from sklearn.decomposition import PCA

# %%
principal = PCA(n_components = 2)
 
X_train = principal.fit_transform(x_train)
X_test = principal.transform(x_test)

# %%
score = principal.explained_variance_ratio_

# %%
score
# Out:
# array([0.82829025, 0.17106358])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    117244
#            1       0.83      0.60      0.70      1449
#
#     accuracy                           0.99    118693
#    macro avg       0.91      0.80      0.85    118693
# weighted avg       0.99      0.99      0.99    118693
