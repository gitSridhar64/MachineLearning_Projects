# %%
import pandas as pd

# %%
data = pd.read_csv('xAPI-Edu-Data.csv')

# %%
data.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %% [markdown]
# # TASK-2.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
data.isnull().any().any()
# Out:
# False

# %% [markdown]
# # TASK-2.1

# %%
data.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# std      30.779223         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
data.duplicated().sum()
# Out:
# 2

# %%
data['Discussion'].unique()
 
data['AnnouncementsView'].unique()
 
data['Class'].unique()
# Out:
# array(['M', 'L', 'H'], dtype=object)

# %% [markdown]
# # TASK-2.4

# %%
#Plotting the unique values
import seaborn as sns
sns.countplot(data['Discussion'])
# Out:
# C:\Users\91700\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Discussion', ylabel='count'>

# %%
#Boxplot
data[['AnnouncementsView']].boxplot()
# Out:
# <AxesSubplot:>

# %%
#Correlation 
data.corr()
# Out:
#                    raisedhands  VisITedResources  AnnouncementsView  \
# raisedhands           1.000000          0.691572           0.643918
# VisITedResources      0.691572          1.000000           0.594500
# AnnouncementsView     0.643918          0.594500           1.000000
# Discussion            0.339386          0.243292           0.417290
#
#                    Discussion
# raisedhands          0.339386
# VisITedResources     0.243292
# AnnouncementsView    0.417290
# Discussion           1.000000

# %%
#Correlation plot
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
data['gender'] = data['gender'].astype("category").cat.codes
data['NationalITy'] = data['NationalITy'].astype("category").cat.codes
data['PlaceofBirth'] = data['PlaceofBirth'].astype("category").cat.codes
data['StageID'] = data['StageID'].astype("category").cat.codes
data['SectionID'] = data['SectionID'].astype("category").cat.codes
data['Topic'] = data['Topic'].astype("category").cat.codes
data['Semester'] = data['Semester'].astype("category").cat.codes
data['Relation'] = data['Relation'].astype("category").cat.codes
data['ParentAnsweringSurvey'] = data['ParentAnsweringSurvey'].astype("category").cat.codes
data['ParentschoolSatisfaction'] = data['ParentschoolSatisfaction'].astype("category").cat.codes
data['Class'] = data['Class'].astype("category").cat.codes

# %%
data.head()
# Out:
#    gender  NationalITy  PlaceofBirth  StageID GradeID  SectionID  Topic  \
# 0       1            4             4        2    G-04          0      7
# 1       1            4             4        2    G-04          0      7
# 2       1            4             4        2    G-04          0      7
# 3       1            4             4        2    G-04          0      7
# 4       1            4             4        2    G-04          0      7
#
#    Semester  Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0         0         0           15                16                  2
# 1         0         0           20                20                  3
# 2         0         0           10                 7                  0
# 3         0         0           30                25                  5
# 4         0         0           40                50                 12
#
#    Discussion  ParentAnsweringSurvey  ParentschoolSatisfaction  \
# ...

# %% [markdown]
# # task-1

# %% [markdown]
# # question: HOW SATISFIED ARE THE PARENTS AS PER THE SEMESTER RESULTS??

# %%
sns.barplot(x = 'Semester',
            y = 'ParentschoolSatisfaction',
            data = data)
 
# Show the plot
plt.show()

# %% [markdown]
# # TASK-2.3

# %%
data.drop(["GradeID", "StudentAbsenceDays"], axis = 1, inplace = True)

# %%
data.head()
# Out:
#    gender  NationalITy  PlaceofBirth  StageID  SectionID  Topic  Semester  \
# 0       1            4             4        2          0      7         0
# 1       1            4             4        2          0      7         0
# 2       1            4             4        2          0      7         0
# 3       1            4             4        2          0      7         0
# 4       1            4             4        2          0      7         0
#
#    Relation  raisedhands  VisITedResources  AnnouncementsView  Discussion  \
# 0         0           15                16                  2          20
# 1         0           20                20                  3          25
# 2         0           10                 7                  0          30
# 3         0           30                25                  5          35
# 4         0           40                50                 12          50
#
#    ParentAnsweringSurvey  ParentschoolSatisfaction  Class
# ...

# %%
x = data.drop(["Class"], axis = 1)
y = data[['Class']]

# %%
x
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  SectionID  Topic  Semester  \
# 0         1            4             4        2          0      7         0
# 1         1            4             4        2          0      7         0
# 2         1            4             4        2          0      7         0
# 3         1            4             4        2          0      7         0
# 4         1            4             4        2          0      7         0
# ..      ...          ...           ...      ...        ...    ...       ...
# 475       0            3             3        1          0      2         1
# 476       0            3             3        1          0      5         0
# 477       0            3             3        1          0      5         1
# 478       0            3             3        1          0      6         0
# 479       0            3             3        1          0      6         1
#
# ...

# %%
y
# Out:
#      Class
# 0        2
# 1        2
# 2        1
# 3        1
# 4        2
# ..     ...
# 475      1
# 476      2
# 477      2
# 478      1
# 479      1
#
# [480 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.5, random_state =0)

# %%
x_train
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  SectionID  Topic  Semester  \
# 410       0            3             3        1          1      1         0
# 322       1            3             3        2          0      4         0
# 108       1            8             8        2          1      7         0
# 368       0            7             3        2          0      0         0
# 218       1            4             4        1          2     11         1
# ..      ...          ...           ...      ...        ...    ...       ...
# 323       1            3             3        2          0      4         1
# 192       1            4             4        1          0      0         1
# 117       0            4             4        2          2      7         0
# 47        0            4             4        0          0      3         0
# 172       1            1             1        2          1      4         1
#
# ...

# %%
y_train
# Out:
#      Class
# 410      0
# 322      1
# 108      2
# 368      0
# 218      0
# ..     ...
# 323      1
# 192      2
# 117      0
# 47       0
# 172      1
#
# [240 rows x 1 columns]

# %%
x_test
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  SectionID  Topic  Semester  \
# 15        0            4             4        1          0      7         0
# 124       1            4             4        2          2      7         0
# 141       1           10            10        1          0      9         1
# 263       1            0             0        2          0      8         1
# 170       1            4             4        2          1      4         1
# ..      ...          ...           ...      ...        ...    ...       ...
# 199       1            4             4        1          1      0         1
# 173       1            9             9        2          1      4         1
# 312       0            3             3        2          1     10         0
# 342       1            3             3        2          1      4         0
# 471       1            7             3        1          0      6         1
#
# ...

# %%
y_test
# Out:
#      Class
# 15       2
# 124      1
# 141      1
# 263      2
# 170      0
# ..     ...
# 199      2
# 173      1
# 312      0
# 342      2
# 471      2
#
# [240 rows x 1 columns]

# %% [markdown]
# # random forest classification

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier()
forest.fit(x_train, y_train)
y_pred = forest.predict(x_test)
# Out:
# C:\Users\91700\AppData\Local\Temp/ipykernel_9824/3583772033.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(x_train, y_train)

# %%
 from sklearn.metrics import accuracy_score
RandomForestClassifier=accuracy_score(y_test, y_pred)
RandomForestClassifier
# Out:
# 0.6791666666666667

# %% [markdown]
# # descision tree

# %%
from sklearn import tree
dtc = tree.DecisionTreeClassifier()
dtc.fit(x_train, y_train)
y_pred_decisiontree = dtc.predict(x_test)
DecisionTree=accuracy_score(y_test, y_pred_decisiontree)
DecisionTree
# Out:
# 0.6375

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(x_train, y_train)
y_predK  =  knn.predict(x_test)
from sklearn.metrics import accuracy_score
KNeighbors=accuracy_score(y_test, y_predK)
KNeighbors
# Out:
# C:\Users\91700\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.6

# %% [markdown]
# # Naive Bayes

# %%
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train, y_train)
y_predG  =  classifier.predict(x_test)
from sklearn.metrics import accuracy_score
Naive_Bayes=accuracy_score(y_test, y_predG)
Naive_Bayes
# Out:
# C:\Users\91700\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 0.6208333333333333
