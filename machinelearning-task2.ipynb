# %%
pip install --upgrade imutils
# Out:
# Requirement already satisfied: imutils in c:\programdata\anaconda3\lib\site-packages (0.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import cv2
import numpy as np
import tensorflow as tf
import os
import matplotlib.pyplot as plt
from tensorflow import keras
from imutils import paths
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Flatten,Dropout
from tensorflow.keras.layers import Conv2D,MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img , img_to_array
from PIL import Image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
import glob

# %%
dataframe = pd.read_csv('filename_to_category_map_surnamesRSTU.csv')

# %%
dataframe.head(10)
# Out:
#        image_id                       cell_type  is_benign localization
# 0  ISIC_0025030  Benign keratosis-like lesions         1.0        scalp
# 1  ISIC_0025661  Benign keratosis-like lesions         1.0        scalp
# 2  ISIC_0027850  Benign keratosis-like lesions         1.0          ear
# 3  ISIC_0025837  Benign keratosis-like lesions         1.0         back
# 4  ISIC_0025209  Benign keratosis-like lesions         1.0         back
# 5  ISIC_0025276  Benign keratosis-like lesions         1.0        trunk
# 6  ISIC_0029396  Benign keratosis-like lesions         1.0        chest
# 7  ISIC_0025767  Benign keratosis-like lesions         1.0        trunk
# 8  ISIC_0029836  Benign keratosis-like lesions         1.0        chest
# 9  ISIC_0032129  Benign keratosis-like lesions         1.0        chest

# %%
import cv2 as cv
folder= list(paths.list_images("ham_data_surnamesRSTU"))

# %%
label1 =[str(f.split("\\")[1]) for f in folder]
label1
# Out:
# ['ISIC_0024306.jpg',
#  'ISIC_0024307.jpg',
#  'ISIC_0024309.jpg',
#  'ISIC_0024310.jpg',
#  'ISIC_0024311.jpg',
#  'ISIC_0024313.jpg',
#  'ISIC_0024315.jpg',
#  'ISIC_0024316.jpg',
#  'ISIC_0024317.jpg',
#  'ISIC_0024318.jpg',
#  'ISIC_0024319.jpg',
#  'ISIC_0024320.jpg',
#  'ISIC_0024322.jpg',
#  'ISIC_0024323.jpg',
#  'ISIC_0024324.jpg',
#  'ISIC_0024325.jpg',
#  'ISIC_0024329.jpg',
#  'ISIC_0024332.jpg',
#  'ISIC_0024333.jpg',
#  'ISIC_0024336.jpg',
#  'ISIC_0024340.jpg',
#  'ISIC_0024347.jpg',
#  'ISIC_0024348.jpg',
#  'ISIC_0024349.jpg',
#  'ISIC_0024353.jpg',
#  'ISIC_0024357.jpg',
#  'ISIC_0024363.jpg',
#  'ISIC_0024364.jpg',
#  'ISIC_0024365.jpg',
#  'ISIC_0024367.jpg',
#  'ISIC_0024369.jpg',
#  'ISIC_0024370.jpg',
#  'ISIC_0024372.jpg',
#  'ISIC_0024373.jpg',
#  'ISIC_0024375.jpg',
#  'ISIC_0024376.jpg',
#  'ISIC_0024377.jpg',
#  'ISIC_0024378.jpg',
#  'ISIC_0024379.jpg',
#  'ISIC_0024385.jpg',
#  'ISIC_0024389.jpg',
#  'ISIC_0024390.jpg',
#  'ISIC_0024391.jpg',
#  'ISIC_0024393.jpg',
#  'ISIC_0024394.jpg',
#  'ISIC_0024397.jpg',
#  'ISIC_0024401.jpg',
#  'ISIC_0024402.jpg',
#  'ISIC_0024403.jpg',
#  'ISIC_0024405.jpg',
#  'ISIC_0024406.jpg',
#  'ISIC_0024408.jpg',
#  'ISIC_0024409.jpg',
#  'ISIC_0024411.jpg',
#  'ISIC_0024416.jpg',
#  'ISIC_0024417.jpg',
#  'ISIC_0024419.jpg',
#  'ISIC_0024420.jpg',
#  'ISIC_0024422.jpg',
#  'ISIC_0024423.jpg',
#  'ISIC_0024425.jpg',
#  'ISIC_0024426.jpg',
#  'ISIC_0024427.jpg',
#  'ISIC_0024429.jpg',
#  'ISIC_0024430.jpg',
#  'ISIC_0024432.jpg',
#  'ISIC_0024433.jpg',
#  'ISIC_0024437.jpg',
#  'ISIC_0024439.jpg',
#  'ISIC_0024442.jpg',
#  'ISIC_0024444.jpg',
#  'ISIC_0024445.jpg',
#  'ISIC_0024447.jpg',
#  'ISIC_0024456.jpg',
#  'ISIC_0024458.jpg',
#  'ISIC_0024459.jpg',
#  'ISIC_0024460.jpg',
#  'ISIC_0024461.jpg',
#  'ISIC_0024463.jpg',
#  'ISIC_0024465.jpg',
#  'ISIC_0024468.jpg',
#  'ISIC_0024473.jpg',
#  'ISIC_0024478.jpg',
#  'ISIC_0024484.jpg',
#  'ISIC_0024486.jpg',
#  'ISIC_0024487.jpg',
#  'ISIC_0024488.jpg',
#  'ISIC_0024489.jpg',
#  'ISIC_0024491.jpg',
#  'ISIC_0024493.jpg',
#  'ISIC_0024497.jpg',
#  'ISIC_0024499.jpg',
#  'ISIC_0024502.jpg',
#  'ISIC_0024506.jpg',
#  'ISIC_0024509.jpg',
#  'ISIC_0024510.jpg',
#  'ISIC_0024512.jpg',
#  'ISIC_0024513.jpg',
#  'ISIC_0024514.jpg',
#  'ISIC_0024516.jpg',
#  'ISIC_0024517.jpg',
#  'ISIC_0024519.jpg',
#  'ISIC_0024520.jpg',
#  'ISIC_0024525.jpg',
#  'ISIC_0024526.jpg',
#  'ISIC_0024527.jpg',
#  'ISIC_0024529.jpg',
#  'ISIC_0024530.jpg',
#  'ISIC_0024533.jpg',
#  'ISIC_0024535.jpg',
#  'ISIC_0024540.jpg',
#  'ISIC_0024542.jpg',
#  'ISIC_0024544.jpg',
#  'ISIC_0024546.jpg',
#  'ISIC_0024547.jpg',
#  'ISIC_0024548.jpg',
#  'ISIC_0024549.jpg',
#  'ISIC_0024551.jpg',
#  'ISIC_0024553.jpg',
#  'ISIC_0024554.jpg',
#  'ISIC_0024556.jpg',
#  'ISIC_0024557.jpg',
#  'ISIC_0024558.jpg',
#  'ISIC_0024559.jpg',
#  'ISIC_0024561.jpg',
#  'ISIC_0024562.jpg',
#  'ISIC_0024566.jpg',
#  'ISIC_0024567.jpg',
#  'ISIC_0024569.jpg',
#  'ISIC_0024570.jpg',
#  'ISIC_0024573.jpg',
#  'ISIC_0024575.jpg',
#  'ISIC_0024576.jpg',
#  'ISIC_0024577.jpg',
#  'ISIC_0024581.jpg',
#  'ISIC_0024584.jpg',
#  'ISIC_0024586.jpg',
#  'ISIC_0024588.jpg',
#  'ISIC_0024590.jpg',
#  'ISIC_0024591.jpg',
#  'ISIC_0024597.jpg',
#  'ISIC_0024599.jpg',
#  'ISIC_0024600.jpg',
#  'ISIC_0024601.jpg',
#  'ISIC_0024609.jpg',
#  'ISIC_0024610.jpg',
#  'ISIC_0024613.jpg',
#  'ISIC_0024615.jpg',
#  'ISIC_0024616.jpg',
#  'ISIC_0024618.jpg',
#  'ISIC_0024619.jpg',
#  'ISIC_0024624.jpg',
#  'ISIC_0024625.jpg',
#  'ISIC_0024634.jpg',
#  'ISIC_0024636.jpg',
#  'ISIC_0024637.jpg',
#  'ISIC_0024639.jpg',
#  'ISIC_0024642.jpg',
#  'ISIC_0024643.jpg',
#  'ISIC_0024644.jpg',
#  'ISIC_0024645.jpg',
#  'ISIC_0024646.jpg',
#  'ISIC_0024649.jpg',
#  'ISIC_0024650.jpg',
#  'ISIC_0024651.jpg',
#  'ISIC_0024652.jpg',
#  'ISIC_0024654.jpg',
#  'ISIC_0024655.jpg',
#  'ISIC_0024657.jpg',
#  'ISIC_0024666.jpg',
#  'ISIC_0024667.jpg',
#  'ISIC_0024671.jpg',
#  'ISIC_0024674.jpg',
#  'ISIC_0024677.jpg',
#  'ISIC_0024678.jpg',
#  'ISIC_0024679.jpg',
#  'ISIC_0024682.jpg',
#  'ISIC_0024685.jpg',
#  'ISIC_0024689.jpg',
#  'ISIC_0024690.jpg',
#  'ISIC_0024693.jpg',
#  'ISIC_0024694.jpg',
#  'ISIC_0024697.jpg',
#  'ISIC_0024698.jpg',
#  'ISIC_0024701.jpg',
#  'ISIC_0024702.jpg',
#  'ISIC_0024703.jpg',
#  'ISIC_0024705.jpg',
#  'ISIC_0024706.jpg',
#  'ISIC_0024707.jpg',
#  'ISIC_0024708.jpg',
#  'ISIC_0024710.jpg',
#  'ISIC_0024712.jpg',
#  'ISIC_0024714.jpg',
#  'ISIC_0024715.jpg',
#  'ISIC_0024718.jpg',
#  'ISIC_0024719.jpg',
#  'ISIC_0024720.jpg',
#  'ISIC_0024723.jpg',
#  'ISIC_0024725.jpg',
#  'ISIC_0024727.jpg',
#  'ISIC_0024728.jpg',
#  'ISIC_0024729.jpg',
#  'ISIC_0024730.jpg',
#  'ISIC_0024731.jpg',
#  'ISIC_0024733.jpg',
#  'ISIC_0024734.jpg',
#  'ISIC_0024738.jpg',
#  'ISIC_0024742.jpg',
#  'ISIC_0024743.jpg',
#  'ISIC_0024744.jpg',
#  'ISIC_0024746.jpg',
#  'ISIC_0024747.jpg',
#  'ISIC_0024748.jpg',
#  'ISIC_0024749.jpg',
#  'ISIC_0024755.jpg',
#  'ISIC_0024759.jpg',
#  'ISIC_0024764.jpg',
#  'ISIC_0024765.jpg',
#  'ISIC_0024767.jpg',
#  'ISIC_0024768.jpg',
#  'ISIC_0024769.jpg',
#  'ISIC_0024772.jpg',
#  'ISIC_0024775.jpg',
#  'ISIC_0024776.jpg',
#  'ISIC_0024782.jpg',
#  'ISIC_0024783.jpg',
#  'ISIC_0024785.jpg',
#  'ISIC_0024788.jpg',
#  'ISIC_0024789.jpg',
#  'ISIC_0024790.jpg',
#  'ISIC_0024791.jpg',
#  'ISIC_0024792.jpg',
#  'ISIC_0024793.jpg',
#  'ISIC_0024794.jpg',
#  'ISIC_0024795.jpg',
#  'ISIC_0024796.jpg',
#  'ISIC_0024797.jpg',
#  'ISIC_0024798.jpg',
#  'ISIC_0024799.jpg',
#  'ISIC_0024800.jpg',
#  'ISIC_0024801.jpg',
#  'ISIC_0024802.jpg',
#  'ISIC_0024805.jpg',
#  'ISIC_0024806.jpg',
#  'ISIC_0024809.jpg',
#  'ISIC_0024810.jpg',
#  'ISIC_0024811.jpg',
#  'ISIC_0024814.jpg',
#  'ISIC_0024815.jpg',
#  'ISIC_0024818.jpg',
#  'ISIC_0024819.jpg',
#  'ISIC_0024821.jpg',
#  'ISIC_0024822.jpg',
#  'ISIC_0024823.jpg',
#  'ISIC_0024824.jpg',
#  'ISIC_0024825.jpg',
#  'ISIC_0024826.jpg',
#  'ISIC_0024827.jpg',
#  'ISIC_0024828.jpg',
#  'ISIC_0024830.jpg',
#  'ISIC_0024832.jpg',
#  'ISIC_0024834.jpg',
#  'ISIC_0024835.jpg',
#  'ISIC_0024836.jpg',
#  'ISIC_0024838.jpg',
#  'ISIC_0024839.jpg',
#  'ISIC_0024841.jpg',
#  'ISIC_0024843.jpg',
#  'ISIC_0024844.jpg',
#  'ISIC_0024845.jpg',
#  'ISIC_0024846.jpg',
#  'ISIC_0024847.jpg',
#  'ISIC_0024849.jpg',
#  'ISIC_0024851.jpg',
#  'ISIC_0024852.jpg',
#  'ISIC_0024853.jpg',
#  'ISIC_0024854.jpg',
#  'ISIC_0024855.jpg',
#  'ISIC_0024856.jpg',
#  'ISIC_0024858.jpg',
#  'ISIC_0024860.jpg',
#  'ISIC_0024864.jpg',
#  'ISIC_0024865.jpg',
#  'ISIC_0024867.jpg',
#  'ISIC_0024869.jpg',
#  'ISIC_0024870.jpg',
#  'ISIC_0024871.jpg',
#  'ISIC_0024872.jpg',
#  'ISIC_0024874.jpg',
#  'ISIC_0024875.jpg',
#  'ISIC_0024876.jpg',
#  'ISIC_0024877.jpg',
#  'ISIC_0024879.jpg',
#  'ISIC_0024880.jpg',
#  'ISIC_0024881.jpg',
#  'ISIC_0024884.jpg',
#  'ISIC_0024886.jpg',
#  'ISIC_0024891.jpg',
#  'ISIC_0024893.jpg',
#  'ISIC_0024894.jpg',
#  'ISIC_0024895.jpg',
#  'ISIC_0024896.jpg',
#  'ISIC_0024897.jpg',
#  'ISIC_0024898.jpg',
#  'ISIC_0024899.jpg',
#  'ISIC_0024902.jpg',
#  'ISIC_0024904.jpg',
#  'ISIC_0024907.jpg',
#  'ISIC_0024908.jpg',
#  'ISIC_0024909.jpg',
#  'ISIC_0024910.jpg',
#  'ISIC_0024911.jpg',
#  'ISIC_0024913.jpg',
#  'ISIC_0024914.jpg',
#  'ISIC_0024916.jpg',
#  'ISIC_0024917.jpg',
#  'ISIC_0024918.jpg',
#  'ISIC_0024924.jpg',
#  'ISIC_0024927.jpg',
#  'ISIC_0024928.jpg',
#  'ISIC_0024931.jpg',
#  'ISIC_0024934.jpg',
#  'ISIC_0024937.jpg',
#  'ISIC_0024938.jpg',
#  'ISIC_0024939.jpg',
#  'ISIC_0024942.jpg',
#  'ISIC_0024943.jpg',
#  'ISIC_0024944.jpg',
#  'ISIC_0024945.jpg',
#  'ISIC_0024949.jpg',
#  'ISIC_0024951.jpg',
#  'ISIC_0024953.jpg',
#  'ISIC_0024954.jpg',
#  'ISIC_0024956.jpg',
#  'ISIC_0024957.jpg',
#  'ISIC_0024958.jpg',
#  'ISIC_0024961.jpg',
#  'ISIC_0024962.jpg',
#  'ISIC_0024963.jpg',
#  'ISIC_0024964.jpg',
#  'ISIC_0024965.jpg',
#  'ISIC_0024966.jpg',
#  'ISIC_0024973.jpg',
#  'ISIC_0024974.jpg',
#  'ISIC_0024975.jpg',
#  'ISIC_0024976.jpg',
#  'ISIC_0024977.jpg',
#  'ISIC_0024978.jpg',
#  'ISIC_0024979.jpg',
#  'ISIC_0024981.jpg',
#  'ISIC_0024982.jpg',
#  'ISIC_0024983.jpg',
#  'ISIC_0024985.jpg',
#  'ISIC_0024986.jpg',
#  'ISIC_0024987.jpg',
#  'ISIC_0024989.jpg',
#  'ISIC_0024993.jpg',
#  'ISIC_0024995.jpg',
#  'ISIC_0024996.jpg',
#  'ISIC_0024997.jpg',
#  'ISIC_0024999.jpg',
#  'ISIC_0025000.jpg',
#  'ISIC_0025003.jpg',
#  'ISIC_0025005.jpg',
#  'ISIC_0025006.jpg',
#  'ISIC_0025009.jpg',
#  'ISIC_0025010.jpg',
#  'ISIC_0025011.jpg',
#  'ISIC_0025012.jpg',
#  'ISIC_0025014.jpg',
#  'ISIC_0025016.jpg',
#  'ISIC_0025017.jpg',
#  'ISIC_0025018.jpg',
#  'ISIC_0025019.jpg',
#  'ISIC_0025022.jpg',
#  'ISIC_0025026.jpg',
#  'ISIC_0025028.jpg',
#  'ISIC_0025029.jpg',
#  'ISIC_0025030.jpg',
#  'ISIC_0025031.jpg',
#  'ISIC_0025032.jpg',
#  'ISIC_0025033.jpg',
#  'ISIC_0025037.jpg',
#  'ISIC_0025039.jpg',
#  'ISIC_0025041.jpg',
#  'ISIC_0025042.jpg',
#  'ISIC_0025049.jpg',
#  'ISIC_0025051.jpg',
#  'ISIC_0025052.jpg',
#  'ISIC_0025055.jpg',
#  'ISIC_0025056.jpg',
#  'ISIC_0025061.jpg',
#  'ISIC_0025063.jpg',
#  'ISIC_0025065.jpg',
#  'ISIC_0025066.jpg',
#  'ISIC_0025068.jpg',
#  'ISIC_0025071.jpg',
#  'ISIC_0025072.jpg',
#  'ISIC_0025073.jpg',
#  'ISIC_0025074.jpg',
#  'ISIC_0025075.jpg',
#  'ISIC_0025079.jpg',
#  'ISIC_0025080.jpg',
#  'ISIC_0025082.jpg',
#  'ISIC_0025084.jpg',
#  'ISIC_0025086.jpg',
#  'ISIC_0025088.jpg',
#  'ISIC_0025089.jpg',
#  'ISIC_0025094.jpg',
#  'ISIC_0025095.jpg',
#  'ISIC_0025098.jpg',
#  'ISIC_0025099.jpg',
#  'ISIC_0025100.jpg',
#  'ISIC_0025101.jpg',
#  'ISIC_0025102.jpg',
#  'ISIC_0025103.jpg',
#  'ISIC_0025104.jpg',
#  'ISIC_0025107.jpg',
#  'ISIC_0025108.jpg',
#  'ISIC_0025109.jpg',
#  'ISIC_0025110.jpg',
#  'ISIC_0025113.jpg',
#  'ISIC_0025115.jpg',
#  'ISIC_0025116.jpg',
#  'ISIC_0025117.jpg',
#  'ISIC_0025118.jpg',
#  'ISIC_0025119.jpg',
#  'ISIC_0025122.jpg',
#  'ISIC_0025123.jpg',
#  'ISIC_0025124.jpg',
#  'ISIC_0025127.jpg',
#  'ISIC_0025128.jpg',
#  'ISIC_0025130.jpg',
#  'ISIC_0025131.jpg',
#  'ISIC_0025135.jpg',
#  'ISIC_0025136.jpg',
#  'ISIC_0025137.jpg',
#  'ISIC_0025138.jpg',
#  'ISIC_0025139.jpg',
#  'ISIC_0025141.jpg',
#  'ISIC_0025142.jpg',
#  'ISIC_0025143.jpg',
#  'ISIC_0025147.jpg',
#  'ISIC_0025148.jpg',
#  'ISIC_0025149.jpg',
#  'ISIC_0025151.jpg',
#  'ISIC_0025153.jpg',
#  'ISIC_0025155.jpg',
#  'ISIC_0025157.jpg',
#  'ISIC_0025160.jpg',
#  'ISIC_0025161.jpg',
#  'ISIC_0025162.jpg',
#  'ISIC_0025163.jpg',
#  'ISIC_0025167.jpg',
#  'ISIC_0025168.jpg',
#  'ISIC_0025169.jpg',
#  'ISIC_0025172.jpg',
#  'ISIC_0025173.jpg',
#  'ISIC_0025175.jpg',
#  'ISIC_0025177.jpg',
#  'ISIC_0025178.jpg',
#  'ISIC_0025180.jpg',
#  'ISIC_0025182.jpg',
#  'ISIC_0025183.jpg',
#  'ISIC_0025185.jpg',
#  'ISIC_0025186.jpg',
#  'ISIC_0025187.jpg',
#  'ISIC_0025190.jpg',
#  'ISIC_0025191.jpg',
#  'ISIC_0025192.jpg',
#  'ISIC_0025195.jpg',
#  'ISIC_0025196.jpg',
#  'ISIC_0025197.jpg',
#  'ISIC_0025198.jpg',
#  'ISIC_0025200.jpg',
#  'ISIC_0025202.jpg',
#  'ISIC_0025203.jpg',
#  'ISIC_0025206.jpg',
#  'ISIC_0025207.jpg',
#  'ISIC_0025209.jpg',
#  'ISIC_0025211.jpg',
#  'ISIC_0025212.jpg',
#  'ISIC_0025213.jpg',
#  'ISIC_0025214.jpg',
#  'ISIC_0025215.jpg',
#  'ISIC_0025216.jpg',
#  'ISIC_0025218.jpg',
#  'ISIC_0025219.jpg',
#  'ISIC_0025228.jpg',
#  'ISIC_0025229.jpg',
#  'ISIC_0025230.jpg',
#  'ISIC_0025231.jpg',
#  'ISIC_0025232.jpg',
#  'ISIC_0025233.jpg',
#  'ISIC_0025236.jpg',
#  'ISIC_0025238.jpg',
#  'ISIC_0025239.jpg',
#  'ISIC_0025240.jpg',
#  'ISIC_0025242.jpg',
#  'ISIC_0025244.jpg',
#  'ISIC_0025245.jpg',
#  'ISIC_0025246.jpg',
#  'ISIC_0025248.jpg',
#  'ISIC_0025249.jpg',
#  'ISIC_0025251.jpg',
#  'ISIC_0025253.jpg',
#  'ISIC_0025257.jpg',
#  'ISIC_0025258.jpg',
#  'ISIC_0025261.jpg',
#  'ISIC_0025264.jpg',
#  'ISIC_0025266.jpg',
#  'ISIC_0025267.jpg',
#  'ISIC_0025268.jpg',
#  'ISIC_0025272.jpg',
#  'ISIC_0025273.jpg',
#  'ISIC_0025274.jpg',
#  'ISIC_0025275.jpg',
#  'ISIC_0025276.jpg',
#  'ISIC_0025278.jpg',
#  'ISIC_0025281.jpg',
#  'ISIC_0025282.jpg',
#  'ISIC_0025283.jpg',
#  'ISIC_0025284.jpg',
#  'ISIC_0025287.jpg',
#  'ISIC_0025288.jpg',
#  'ISIC_0025289.jpg',
#  'ISIC_0025291.jpg',
#  'ISIC_0025292.jpg',
#  'ISIC_0025293.jpg',
#  'ISIC_0025294.jpg',
#  'ISIC_0025295.jpg',
#  'ISIC_0025296.jpg',
#  'ISIC_0025297.jpg',
#  'ISIC_0025299.jpg',
#  'ISIC_0025302.jpg',
#  'ISIC_0025303.jpg',
#  'ISIC_0025308.jpg',
#  'ISIC_0025310.jpg',
#  'ISIC_0025311.jpg',
#  'ISIC_0025313.jpg',
#  'ISIC_0025317.jpg',
#  'ISIC_0025318.jpg',
#  'ISIC_0025320.jpg',
#  'ISIC_0025321.jpg',
#  'ISIC_0025326.jpg',
#  'ISIC_0025328.jpg',
#  'ISIC_0025329.jpg',
#  'ISIC_0025332.jpg',
#  'ISIC_0025333.jpg',
#  'ISIC_0025334.jpg',
#  'ISIC_0025336.jpg',
#  'ISIC_0025339.jpg',
#  'ISIC_0025340.jpg',
#  'ISIC_0025341.jpg',
#  'ISIC_0025342.jpg',
#  'ISIC_0025343.jpg',
#  'ISIC_0025344.jpg',
#  'ISIC_0025345.jpg',
#  'ISIC_0025352.jpg',
#  'ISIC_0025353.jpg',
#  'ISIC_0025354.jpg',
#  'ISIC_0025355.jpg',
#  'ISIC_0025357.jpg',
#  'ISIC_0025361.jpg',
#  'ISIC_0025363.jpg',
#  'ISIC_0025364.jpg',
#  'ISIC_0025365.jpg',
#  'ISIC_0025370.jpg',
#  'ISIC_0025374.jpg',
#  'ISIC_0025375.jpg',
#  'ISIC_0025377.jpg',
#  'ISIC_0025379.jpg',
#  'ISIC_0025380.jpg',
#  'ISIC_0025382.jpg',
#  'ISIC_0025384.jpg',
#  'ISIC_0025385.jpg',
#  'ISIC_0025388.jpg',
#  'ISIC_0025391.jpg',
#  'ISIC_0025392.jpg',
#  'ISIC_0025393.jpg',
#  'ISIC_0025395.jpg',
#  'ISIC_0025398.jpg',
#  'ISIC_0025399.jpg',
#  'ISIC_0025400.jpg',
#  'ISIC_0025402.jpg',
#  'ISIC_0025403.jpg',
#  'ISIC_0025405.jpg',
#  'ISIC_0025406.jpg',
#  'ISIC_0025409.jpg',
#  'ISIC_0025410.jpg',
#  'ISIC_0025413.jpg',
#  'ISIC_0025417.jpg',
#  'ISIC_0025418.jpg',
#  'ISIC_0025422.jpg',
#  'ISIC_0025423.jpg',
#  'ISIC_0025424.jpg',
#  'ISIC_0025425.jpg',
#  'ISIC_0025427.jpg',
#  'ISIC_0025430.jpg',
#  'ISIC_0025432.jpg',
#  'ISIC_0025439.jpg',
#  'ISIC_0025440.jpg',
#  'ISIC_0025442.jpg',
#  'ISIC_0025444.jpg',
#  'ISIC_0025447.jpg',
#  'ISIC_0025448.jpg',
#  'ISIC_0025449.jpg',
#  'ISIC_0025450.jpg',
#  'ISIC_0025453.jpg',
#  'ISIC_0025456.jpg',
#  'ISIC_0025458.jpg',
#  'ISIC_0025461.jpg',
#  'ISIC_0025464.jpg',
#  'ISIC_0025469.jpg',
#  'ISIC_0025471.jpg',
#  'ISIC_0025472.jpg',
#  'ISIC_0025474.jpg',
#  'ISIC_0025475.jpg',
#  'ISIC_0025476.jpg',
#  'ISIC_0025477.jpg',
#  'ISIC_0025482.jpg',
#  'ISIC_0025486.jpg',
#  'ISIC_0025489.jpg',
#  'ISIC_0025492.jpg',
#  'ISIC_0025495.jpg',
#  'ISIC_0025497.jpg',
#  'ISIC_0025502.jpg',
#  'ISIC_0025505.jpg',
#  'ISIC_0025508.jpg',
#  'ISIC_0025509.jpg',
#  'ISIC_0025510.jpg',
#  'ISIC_0025512.jpg',
#  'ISIC_0025517.jpg',
#  'ISIC_0025518.jpg',
#  'ISIC_0025520.jpg',
#  'ISIC_0025523.jpg',
#  'ISIC_0025525.jpg',
#  'ISIC_0025526.jpg',
#  'ISIC_0025529.jpg',
#  'ISIC_0025532.jpg',
#  'ISIC_0025535.jpg',
#  'ISIC_0025536.jpg',
#  'ISIC_0025537.jpg',
#  'ISIC_0025540.jpg',
#  'ISIC_0025541.jpg',
#  'ISIC_0025543.jpg',
#  'ISIC_0025545.jpg',
#  'ISIC_0025546.jpg',
#  'ISIC_0025553.jpg',
#  'ISIC_0025554.jpg',
#  'ISIC_0025558.jpg',
#  'ISIC_0025559.jpg',
#  'ISIC_0025561.jpg',
#  'ISIC_0025562.jpg',
#  'ISIC_0025563.jpg',
#  'ISIC_0025565.jpg',
#  'ISIC_0025567.jpg',
#  'ISIC_0025569.jpg',
#  'ISIC_0025571.jpg',
#  'ISIC_0025572.jpg',
#  'ISIC_0025577.jpg',
#  'ISIC_0025578.jpg',
#  'ISIC_0025580.jpg',
#  'ISIC_0025581.jpg',
#  'ISIC_0025583.jpg',
#  'ISIC_0025589.jpg',
#  'ISIC_0025591.jpg',
#  'ISIC_0025592.jpg',
#  'ISIC_0025594.jpg',
#  'ISIC_0025595.jpg',
#  'ISIC_0025596.jpg',
#  'ISIC_0025597.jpg',
#  'ISIC_0025599.jpg',
#  'ISIC_0025600.jpg',
#  'ISIC_0025601.jpg',
#  'ISIC_0025602.jpg',
#  'ISIC_0025603.jpg',
#  'ISIC_0025604.jpg',
#  'ISIC_0025609.jpg',
#  'ISIC_0025610.jpg',
#  'ISIC_0025614.jpg',
#  'ISIC_0025617.jpg',
#  'ISIC_0025618.jpg',
#  'ISIC_0025619.jpg',
#  'ISIC_0025621.jpg',
#  'ISIC_0025622.jpg',
#  'ISIC_0025623.jpg',
#  'ISIC_0025624.jpg',
#  'ISIC_0025625.jpg',
#  'ISIC_0025626.jpg',
#  'ISIC_0025628.jpg',
#  'ISIC_0025632.jpg',
#  'ISIC_0025633.jpg',
#  'ISIC_0025634.jpg',
#  'ISIC_0025636.jpg',
#  'ISIC_0025637.jpg',
#  'ISIC_0025638.jpg',
#  'ISIC_0025639.jpg',
#  'ISIC_0025643.jpg',
#  'ISIC_0025644.jpg',
#  'ISIC_0025645.jpg',
#  'ISIC_0025647.jpg',
#  'ISIC_0025649.jpg',
#  'ISIC_0025650.jpg',
#  'ISIC_0025653.jpg',
#  'ISIC_0025654.jpg',
#  'ISIC_0025655.jpg',
#  'ISIC_0025657.jpg',
#  'ISIC_0025658.jpg',
#  'ISIC_0025659.jpg',
#  'ISIC_0025661.jpg',
#  'ISIC_0025662.jpg',
#  'ISIC_0025663.jpg',
#  'ISIC_0025666.jpg',
#  'ISIC_0025667.jpg',
#  'ISIC_0025668.jpg',
#  'ISIC_0025669.jpg',
#  'ISIC_0025670.jpg',
#  'ISIC_0025671.jpg',
#  'ISIC_0025672.jpg',
#  'ISIC_0025673.jpg',
#  'ISIC_0025675.jpg',
#  'ISIC_0025676.jpg',
#  'ISIC_0025680.jpg',
#  'ISIC_0025681.jpg',
#  'ISIC_0025682.jpg',
#  'ISIC_0025687.jpg',
#  'ISIC_0025690.jpg',
#  'ISIC_0025691.jpg',
#  'ISIC_0025692.jpg',
#  'ISIC_0025693.jpg',
#  'ISIC_0025695.jpg',
#  'ISIC_0025696.jpg',
#  'ISIC_0025698.jpg',
#  'ISIC_0025699.jpg',
#  'ISIC_0025700.jpg',
#  'ISIC_0025704.jpg',
#  'ISIC_0025706.jpg',
#  'ISIC_0025707.jpg',
#  'ISIC_0025708.jpg',
#  'ISIC_0025709.jpg',
#  'ISIC_0025710.jpg',
#  'ISIC_0025712.jpg',
#  'ISIC_0025713.jpg',
#  'ISIC_0025717.jpg',
#  'ISIC_0025718.jpg',
#  'ISIC_0025719.jpg',
#  'ISIC_0025721.jpg',
#  'ISIC_0025723.jpg',
#  'ISIC_0025728.jpg',
#  'ISIC_0025730.jpg',
#  'ISIC_0025731.jpg',
#  'ISIC_0025732.jpg',
#  'ISIC_0025736.jpg',
#  'ISIC_0025739.jpg',
#  'ISIC_0025740.jpg',
#  'ISIC_0025741.jpg',
#  'ISIC_0025742.jpg',
#  'ISIC_0025743.jpg',
#  'ISIC_0025745.jpg',
#  'ISIC_0025748.jpg',
#  'ISIC_0025749.jpg',
#  'ISIC_0025751.jpg',
#  'ISIC_0025752.jpg',
#  'ISIC_0025754.jpg',
#  'ISIC_0025762.jpg',
#  'ISIC_0025764.jpg',
#  'ISIC_0025767.jpg',
#  'ISIC_0025768.jpg',
#  'ISIC_0025769.jpg',
#  'ISIC_0025770.jpg',
#  'ISIC_0025771.jpg',
#  'ISIC_0025772.jpg',
#  'ISIC_0025773.jpg',
#  'ISIC_0025775.jpg',
#  'ISIC_0025780.jpg',
#  'ISIC_0025782.jpg',
#  'ISIC_0025783.jpg',
#  'ISIC_0025784.jpg',
#  'ISIC_0025790.jpg',
#  'ISIC_0025791.jpg',
#  'ISIC_0025794.jpg',
#  'ISIC_0025795.jpg',
#  'ISIC_0025796.jpg',
#  'ISIC_0025797.jpg',
#  'ISIC_0025799.jpg',
#  'ISIC_0025800.jpg',
#  'ISIC_0025802.jpg',
#  'ISIC_0025803.jpg',
#  'ISIC_0025804.jpg',
#  'ISIC_0025805.jpg',
#  'ISIC_0025807.jpg',
#  'ISIC_0025808.jpg',
#  'ISIC_0025809.jpg',
#  'ISIC_0025811.jpg',
#  'ISIC_0025812.jpg',
#  'ISIC_0025814.jpg',
#  'ISIC_0025815.jpg',
#  'ISIC_0025816.jpg',
#  'ISIC_0025819.jpg',
#  'ISIC_0025820.jpg',
#  'ISIC_0025823.jpg',
#  'ISIC_0025824.jpg',
#  'ISIC_0025825.jpg',
#  'ISIC_0025828.jpg',
#  'ISIC_0025829.jpg',
#  'ISIC_0025830.jpg',
#  'ISIC_0025831.jpg',
#  'ISIC_0025834.jpg',
#  'ISIC_0025837.jpg',
#  'ISIC_0025838.jpg',
#  'ISIC_0025840.jpg',
#  'ISIC_0025841.jpg',
#  'ISIC_0025842.jpg',
#  'ISIC_0025843.jpg',
#  'ISIC_0025849.jpg',
#  'ISIC_0025850.jpg',
#  'ISIC_0025851.jpg',
#  'ISIC_0025852.jpg',
#  'ISIC_0025854.jpg',
#  'ISIC_0025860.jpg',
#  'ISIC_0025861.jpg',
#  'ISIC_0025862.jpg',
#  'ISIC_0025863.jpg',
#  'ISIC_0025864.jpg',
#  'ISIC_0025865.jpg',
#  'ISIC_0025866.jpg',
#  'ISIC_0025867.jpg',
#  'ISIC_0025868.jpg',
#  'ISIC_0025871.jpg',
#  'ISIC_0025874.jpg',
#  'ISIC_0025877.jpg',
#  'ISIC_0025880.jpg',
#  'ISIC_0025881.jpg',
#  'ISIC_0025882.jpg',
#  'ISIC_0025884.jpg',
#  'ISIC_0025885.jpg',
#  'ISIC_0025887.jpg',
#  'ISIC_0025888.jpg',
#  'ISIC_0025890.jpg',
#  'ISIC_0025895.jpg',
#  'ISIC_0025897.jpg',
#  'ISIC_0025898.jpg',
#  'ISIC_0025900.jpg',
#  'ISIC_0025901.jpg',
#  'ISIC_0025903.jpg',
#  'ISIC_0025905.jpg',
#  'ISIC_0025906.jpg',
#  'ISIC_0025907.jpg',
#  'ISIC_0025910.jpg',
#  'ISIC_0025916.jpg',
#  'ISIC_0025918.jpg',
#  'ISIC_0025919.jpg',
#  'ISIC_0025920.jpg',
#  'ISIC_0025922.jpg',
#  'ISIC_0025923.jpg',
#  'ISIC_0025925.jpg',
#  'ISIC_0025927.jpg',
#  'ISIC_0025928.jpg',
#  'ISIC_0025930.jpg',
#  'ISIC_0025931.jpg',
#  'ISIC_0025935.jpg',
#  'ISIC_0025936.jpg',
#  'ISIC_0025937.jpg',
#  'ISIC_0025938.jpg',
#  'ISIC_0025939.jpg',
#  'ISIC_0025941.jpg',
#  'ISIC_0025942.jpg',
#  'ISIC_0025943.jpg',
#  'ISIC_0025945.jpg',
#  'ISIC_0025948.jpg',
#  'ISIC_0025951.jpg',
#  'ISIC_0025952.jpg',
#  'ISIC_0025953.jpg',
#  'ISIC_0025955.jpg',
#  'ISIC_0025957.jpg',
#  'ISIC_0025958.jpg',
#  'ISIC_0025959.jpg',
#  'ISIC_0025960.jpg',
#  'ISIC_0025961.jpg',
#  'ISIC_0025962.jpg',
#  'ISIC_0025963.jpg',
#  'ISIC_0025967.jpg',
#  'ISIC_0025969.jpg',
#  'ISIC_0025971.jpg',
#  'ISIC_0025973.jpg',
#  'ISIC_0025975.jpg',
#  'ISIC_0025977.jpg',
#  'ISIC_0025980.jpg',
#  'ISIC_0025984.jpg',
#  'ISIC_0025985.jpg',
#  'ISIC_0025986.jpg',
#  'ISIC_0025987.jpg',
#  'ISIC_0025988.jpg',
#  'ISIC_0025989.jpg',
#  'ISIC_0025992.jpg',
#  'ISIC_0025993.jpg',
#  'ISIC_0025994.jpg',
#  'ISIC_0025995.jpg',
#  'ISIC_0025996.jpg',
#  'ISIC_0025997.jpg',
#  'ISIC_0026000.jpg',
#  'ISIC_0026001.jpg',
#  'ISIC_0026003.jpg',
#  'ISIC_0026004.jpg',
#  'ISIC_0026005.jpg',
#  'ISIC_0026007.jpg',
#  'ISIC_0026008.jpg',
#  'ISIC_0026010.jpg',
#  'ISIC_0026013.jpg',
#  'ISIC_0026014.jpg',
#  'ISIC_0026018.jpg',
#  'ISIC_0026019.jpg',
#  'ISIC_0026022.jpg',
#  'ISIC_0026027.jpg',
#  'ISIC_0026029.jpg',
#  'ISIC_0026032.jpg',
#  'ISIC_0026033.jpg',
#  'ISIC_0026034.jpg',
#  'ISIC_0026035.jpg',
#  'ISIC_0026041.jpg',
#  'ISIC_0026043.jpg',
#  'ISIC_0026044.jpg',
#  'ISIC_0026048.jpg',
#  'ISIC_0026053.jpg',
#  'ISIC_0026054.jpg',
#  'ISIC_0026056.jpg',
#  'ISIC_0026057.jpg',
#  'ISIC_0026058.jpg',
#  'ISIC_0026059.jpg',
#  'ISIC_0026060.jpg',
#  'ISIC_0026062.jpg',
#  'ISIC_0026063.jpg',
#  'ISIC_0026064.jpg',
#  'ISIC_0026065.jpg',
#  'ISIC_0026066.jpg',
#  'ISIC_0026067.jpg',
#  'ISIC_0026068.jpg',
#  'ISIC_0026069.jpg',
#  'ISIC_0026071.jpg',
#  'ISIC_0026074.jpg',
#  'ISIC_0026075.jpg',
#  'ISIC_0026077.jpg',
#  'ISIC_0026079.jpg',
#  'ISIC_0026081.jpg',
#  'ISIC_0026083.jpg',
#  'ISIC_0026087.jpg',
#  'ISIC_0026089.jpg',
#  'ISIC_0026090.jpg',
#  'ISIC_0026093.jpg',
#  'ISIC_0026094.jpg',
#  'ISIC_0026096.jpg',
#  'ISIC_0026103.jpg',
#  'ISIC_0026105.jpg',
#  'ISIC_0026107.jpg',
#  'ISIC_0026110.jpg',
#  'ISIC_0026112.jpg',
#  'ISIC_0026113.jpg',
#  'ISIC_0026115.jpg',
#  'ISIC_0026117.jpg',
#  'ISIC_0026118.jpg',
#  'ISIC_0026120.jpg',
#  'ISIC_0026123.jpg',
#  'ISIC_0026126.jpg',
#  'ISIC_0026127.jpg',
#  'ISIC_0026128.jpg',
#  'ISIC_0026130.jpg',
#  'ISIC_0026132.jpg',
#  'ISIC_0026135.jpg',
#  'ISIC_0026139.jpg',
#  'ISIC_0026142.jpg',
#  'ISIC_0026144.jpg',
#  'ISIC_0026145.jpg',
#  'ISIC_0026146.jpg',
#  'ISIC_0026147.jpg',
#  'ISIC_0026150.jpg',
#  'ISIC_0026152.jpg',
#  'ISIC_0026153.jpg',
#  'ISIC_0026154.jpg',
#  'ISIC_0026155.jpg',
#  'ISIC_0026158.jpg',
#  'ISIC_0026160.jpg',
#  'ISIC_0026162.jpg',
#  'ISIC_0026165.jpg',
#  'ISIC_0026166.jpg',
#  'ISIC_0026168.jpg',
#  'ISIC_0026169.jpg',
#  'ISIC_0026170.jpg',
#  'ISIC_0026172.jpg',
#  'ISIC_0026174.jpg',
#  'ISIC_0026177.jpg',
#  'ISIC_0026180.jpg',
#  'ISIC_0026182.jpg',
#  'ISIC_0026184.jpg',
#  'ISIC_0026186.jpg',
#  'ISIC_0026188.jpg',
#  'ISIC_0026190.jpg',
#  'ISIC_0026191.jpg',
#  'ISIC_0026192.jpg',
#  ...]

# %%
folder1 =[str(f.split("\\")[0]) for f in folder]
folder1
# Out:
# ['ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  'ham_data_surnamesRSTU',
#  ...]

# %%
dataframe["label1"]=label1

# %%
dataframe["folder1"]=folder1

# %%
dataframe.head()
# Out:
#        image_id                       cell_type  is_benign localization  \
# 0  ISIC_0025030  Benign keratosis-like lesions         1.0        scalp
# 1  ISIC_0025661  Benign keratosis-like lesions         1.0        scalp
# 2  ISIC_0027850  Benign keratosis-like lesions         1.0          ear
# 3  ISIC_0025837  Benign keratosis-like lesions         1.0         back
# 4  ISIC_0025209  Benign keratosis-like lesions         1.0         back
#
#                  folder1            label1
# 0  ham_data_surnamesRSTU  ISIC_0024306.jpg
# 1  ham_data_surnamesRSTU  ISIC_0024307.jpg
# 2  ham_data_surnamesRSTU  ISIC_0024309.jpg
# 3  ham_data_surnamesRSTU  ISIC_0024310.jpg
# 4  ham_data_surnamesRSTU  ISIC_0024311.jpg

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(dataframe, test_size= 0.2)
train1=train.reset_index()
test1=test.reset_index()
train2 = train1.drop(['index'] , axis=1)
test2 = test1.drop(['index'] , axis=1)

# %%
train2.info
# Out:
# <bound method DataFrame.info of           image_id                       cell_type  is_benign  \
# 0     ISIC_0031418                Melanocytic nevi        1.0
# 1     ISIC_0029601                Melanocytic nevi        1.0
# 2     ISIC_0025328                Melanocytic nevi        1.0
# 3     ISIC_0025497                Melanocytic nevi        1.0
# 4     ISIC_0026774                        Melanoma        0.0
# ...            ...                             ...        ...
# 4291  ISIC_0030424                Melanocytic nevi        1.0
# 4292  ISIC_0028628  Benign keratosis-like lesions         1.0
# 4293  ISIC_0028378                Melanocytic nevi        1.0
# 4294  ISIC_0032691                Melanocytic nevi        1.0
# 4295  ISIC_0029930               Actinic keratoses        0.0
#
#          localization                folder1            label1
# 0     lower extremity  ham_data_surnamesRSTU  ISIC_0030703.jpg
# 1     upper extremity  ham_data_surnamesRSTU  ISIC_0030283.jpg
# 2               trunk  ham_data_surnamesRSTU  ISIC_0027710.jpg
# 3     upper extremity  ham_data_surnamesRSTU  ISIC_0029838.jpg
# 4     upper extremity  ham_data_surnamesRSTU  ISIC_0026346.jpg
# ...               ...                    ...               ...
# 4291          abdomen  ham_data_surnamesRSTU  ISIC_0029886.jpg
# 4292  lower extremity  ham_data_surnamesRSTU  ISIC_0024973.jpg
# 4293             back  ham_data_surnamesRSTU  ISIC_0032437.jpg
# 4294          abdomen  ham_data_surnamesRSTU  ISIC_0030960.jpg
# 4295             face  ham_data_surnamesRSTU  ISIC_0033411.jpg
#
# [4296 rows x 6 columns]>

# %%
IMG_SIZE= 250

# %%
data1= train2

# %%
x_train=[]
y_train=[]
for t in range(len(data1)):
    folder = data1["folder1"][t]
    file1 = data1["label1"][t]
    image = cv2.imread(os.path.join(folder, file1),cv2.IMREAD_GRAYSCALE)  
    image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
    image = image/255.0
    image = image.reshape(-1,IMG_SIZE,IMG_SIZE,1)
    image = image.reshape(image.shape[1], image.shape[2])
    if t % 500 == 0:
        print(t)
    x_train.append(image)
    y_train.append(data1["label1"][t])
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000

# %%
x_train = np.array(x_train)
print("x_train done")
y_train = np.array(pd.get_dummies(y_train), dtype= np.uint8)
# Out:
# x_train done

# %%
x_train = x_train.reshape(-1,IMG_SIZE,IMG_SIZE, 1)

# %%
data2=test2

# %%
x_test=[]
y_test=[]
for t in range(len(data2)):
    folder = data2["folder1"][t]
    file1= data2["label1"][t]
    image = cv2.imread(os.path.join(folder, file1),cv2.IMREAD_GRAYSCALE) 
    image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
    image = image/255.0
    image = image.reshape(1,IMG_SIZE,IMG_SIZE,1) 
    image = image.reshape(image.shape[1], image.shape[2])
    if t % 100 == 0:
        print(t)
    x_test.append(image)
    y_test.append(data2["label1"][t])
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000

# %%
x_test = np.array(x_test)
print("x_test done")
y_test = np.array(pd.get_dummies(y_test), dtype= np.uint8)
# Out:
# x_test done

# %%
x_test = x_test.reshape(-1,IMG_SIZE,IMG_SIZE, 1)

# %%
x_train.shape
# Out:
# (4296, 250, 250, 1)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from keras.layers import Dropout, Conv2D, Dense, BatchNormalization, MaxPooling2D, Flatten,Activation, Dense

# %%
model = Sequential()
model.add(Conv2D(64, 3, 3, padding = 'same', input_shape=(x_train.shape[1:])))
model.add(Activation('relu'))
BatchNormalization(axis=1)
model.add(Conv2D(64,3,3 , padding = 'same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
BatchNormalization()
model.add(Dense(512))
model.add(Activation('relu'))
BatchNormalization()
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy', optimizer = "adam", metrics = ["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 84, 84, 64)        640
# _________________________________________________________________
# activation (Activation)      (None, 84, 84, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               6423040
# _________________________________________________________________
# activation_2 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# _________________________________________________________________
# activation_3 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 6,461,634
# Trainable params: 6,461,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train = np.asarray(y_train).astype('float32').reshape((-1,1))
y_test = np.asarray(y_test).astype('float32').reshape((-1,1))
